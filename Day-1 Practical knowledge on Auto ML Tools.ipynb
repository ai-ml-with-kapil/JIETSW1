# %% [markdown]
# # Day-1 Practical knowledge on Auto ML Tools

# %% [markdown]
# ## Practical Session

# %% [markdown]
# - To install pycaret use below command
#
# ``` python
# pip install pycaret
#
# ```

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
data = pd.read_pickle("data.pkl")

# %%
data.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# ### PyCaret
# ![image.png](attachment:image.png)

# %%
from pycaret.classification import *

# %%
s = setup(data, target = 'Class variable')
# Out:
# <style type="text/css">
# #T_ab250_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ab250">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab250_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ab250_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab250_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab250_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_ab250_row0_col1" class="data row0 col1" >809</td>
#     </tr>
#     <tr>
#       <th id="T_ab250_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ab250_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ab250_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_ab250_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_c5948 th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=809, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(best, "MyModel.pkl")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[],
#                                        target='Class variable',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeri...
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
# ...

# %%
load_model("MyModel.pkl")
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[],
#                                       target='Class variable',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeri...
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
# ...
